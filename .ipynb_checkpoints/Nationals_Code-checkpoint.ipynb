# %%
import pandas as pd
import numpy as np
import plotly as py
import plotly.graph_objs as go
py.offline.init_notebook_mode(connected=True)
from scipy.signal import argrelextrema
import datetime
import plotly.io as pio
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
nats_season=pd.read_csv('Before_Bryce_Harper_Decision_Nats.csv')

# %%
# nats_season[nats_season['median_ticket_price']==nats_season['median_ticket_price'].min()]

# %%
random_x = nats_season['date']
random_y = nats_season['median_ticket_price']

trace = go.Scatter(
    x = random_x,
    y = random_y
)

title=f'Median Ticket Prices of Washington Nationals Games: {datetime.datetime.today().strftime("%Y-%m-%d")}'

layout = {'title':title,
          'yaxis': {
        'title': 'Median Ticket Price ($)'
    },
    'shapes': [
        # Line Vertical
        {
            'type': 'line',
            'x0': '2019-03-28',
            'x1':'2019-03-28',
            'y0': 0,
            'y1':250,
            'line': {
                'color': 'green',
                'width': 3,
                'dash':'dashdot'
            },
        }
       
    ]
}

data = [trace]
fig = {
    'data': data,
    'layout': layout,
}
py.offline.iplot(fig)
pio.write_image(fig, 'Images/nats_all_games.png')
# Out:
# <div id="f9bf21a4-363e-4ae1-9598-a52b934d17e6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f9bf21a4-363e-4ae1-9598-a52b934d17e6", [{"x": ["2019-02-25", "2019-02-26", "2019-02-27", "2019-02-28", "2019-03-01", "2019-03-02", "2019-03-03", "2019-03-04", "2019-03-05", "2019-03-07", "2019-03-08", "2019-03-09", "2019-03-10", "2019-03-11", "2019-03-12", "2019-03-13", "2019-03-14", "2019-03-15", "2019-03-16", "2019-03-17", "2019-03-18", "2019-03-18", "2019-03-19", "2019-03-21", "2019-03-22", "2019-03-23", "2019-03-24", "2019-03-24", "2019-03-25", "2019-03-28", "2019-03-30", "2019-03-31", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-12", "2019-04-13", "2019-04-14", "2019-04-16", "2019-04-17", "2019-04-18", "2019-04-19", "2019-04-20", "2019-04-21", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-26", "2019-04-27", "2019-04-28", "2019-04-29", "2019-04-30", "2019-05-01", "2019-05-02", "2019-05-03", "2019-05-04", "2019-05-05", "2019-05-06", "2019-05-07", "2019-05-08", "2019-05-09", "2019-05-10", "2019-05-11", "2019-05-12", "2019-05-14", "2019-05-15", "2019-05-16", "2019-05-17", "2019-05-18", "2019-05-19", "2019-05-20", "2019-05-21", "2019-05-22", "2019-05-23", "2019-05-24", "2019-05-25", "2019-05-26", "2019-05-27", "2019-05-28", "2019-05-29", "2019-05-31", "2019-06-01", "2019-06-02", "2019-06-04", "2019-06-05", "2019-06-06", "2019-06-07", "2019-06-08", "2019-06-09", "2019-06-10", "2019-06-11", "2019-06-13", "2019-06-14", "2019-06-15", "2019-06-16", "2019-06-17", "2019-06-18", "2019-06-19", "2019-06-20", "2019-06-21", "2019-06-22", "2019-06-23", "2019-06-25", "2019-06-26", "2019-06-27", "2019-06-28", "2019-06-29", "2019-06-30", "2019-07-02", "2019-07-03", "2019-07-04", "2019-07-05", "2019-07-06", "2019-07-07", "2019-07-12", "2019-07-13", "2019-07-14", "2019-07-16", "2019-07-17", "2019-07-18", "2019-07-19", "2019-07-20", "2019-07-21", "2019-07-22", "2019-07-23", "2019-07-24", "2019-07-25", "2019-07-26", "2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-27", "2019-08-28", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-14", "2019-09-15", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-20", "2019-09-21", "2019-09-22", "2019-09-23", "2019-09-24", "2019-09-25", "2019-09-26", "2019-09-27", "2019-09-28", "2019-09-29"], "y": [27, 37, 36, 37, 32, 50, 65, 30, 131, 77, 48, 52, 78, 63, 62, 50, 44, 65, 81, 73, 45, 53, 69, 70, 56, 81, 62, 74, 78, 210, 73, 69, 168, 126, 159, 82, 83, 77, 71, 78, 82, 93, 80, 99, 84, 96, 86, 82, 77, 43, 44, 44, 86, 95, 83, 55, 51, 52, 54, 93, 107, 95, 51, 54, 67, 101, 94, 113, 111, 64, 82, 67, 111, 122, 84, 46, 36, 42, 35, 66, 73, 67, 75, 77, 68, 77, 91, 69, 68, 81, 68, 78, 75, 70, 91, 96, 77, 81, 104, 105, 104, 102, 100, 105, 82, 81, 81, 80, 82, 76, 90, 100, 91, 86, 108, 103, 99, 99, 87, 107, 112, 104, 105, 117, 87, 91, 114, 87, 80, 77, 80, 79, 106, 113, 92, 73, 68, 69, 85, 88, 77, 79, 82, 102, 69, 81, 71, 50, 47, 49, 90, 89, 78, 72, 69, 83, 63, 171, 208, 159, 71, 72, 84, 83, 81, 68, 47, 48, 75, 85, 91, 79, 39, 65, 74, 67, 65, 63, 94, 88, 89, 75, 77, 81, 108, 104, 104, 114, 64, 63, 62], "type": "scatter", "uid": "0320d746-7497-4a1a-a888-af6fc726c031"}], {"shapes": [{"line": {"color": "green", "dash": "dashdot", "width": 3}, "type": "line", "x0": "2019-03-28", "x1": "2019 ...

# %%
local_maxima=argrelextrema(nats_season['median_ticket_price'].values, np.greater)
nats_season.iloc[local_maxima]
# Out:
#      Unnamed: 0                                              event  \
# 1             1  Spring Training: St. Louis Cardinals at Washin...
# 3             3  Spring Training: Washington Nationals at Bosto...
# 6             6  Spring Training: Houston Astros at Washington ...
# 8             8  Spring Training: Boston Red Sox at Washington ...
# 12           12  Spring Training: Washington Nationals at Houst...
# 18           18  Spring Training: St. Louis Cardinals at Washin...
# 95              Away  2019-06-11  19:10
# 99              Home  2019-06-16  13:35
# 103             Home  2019-06-20  19:05
# 108             Away  2019-06-26  19:10
# 111             Away  2019-06-29  16:10
# 114             Home  2019-07-03  18:05
# 120             Away  2019-07-13  19:15
# 123             Away  2019-07-17  19:05
# 126             Away  2019-07-20  19:20
# 130             Home  2019-07-24  19:05
# 133             Home  2019-07-27  16:05
# 139             Away  2019-08-03  17:10
# 143             Away  2019-08-07  12:45
# 145             Away  2019-08-10  19:10
# 150             Home  2019-08-16  19:05
# 155             Away  2019-08-21  19:05
# 158             Away  2019-08-24  13:20
# 162             Home  2019-08-30  19:05
# 170             Away  2019-09-07  19:20
# 174             Away  2019-09-12  18:40
# 178             Away  2019-09-16  18:45
# 180             Away  2019-09-18  12:15
# 184             Home  2019-09-23  19:05
# 187             Home  2019-09-26  16:05

# %%
reg_season=nats_season[nats_season['date']>='2019-03-28']

# %%
avg_price_by_opp=pd.DataFrame(reg_season.groupby(['opponent'])['median_ticket_price'].mean())

# %%
# avg_price_by_opp

# %%
avg_price_by_opp.reset_index(inplace=True)

# %%
formatted_price=[]
for i in range(len(avg_price_by_opp['median_ticket_price'])):
    formatted_price.append('${:,.2f}'.format(avg_price_by_opp['median_ticket_price'][i]))
avg_price_by_opp['formatted_median_ticket_price']=formatted_price

# %%
# avg_price_by_opp['formatted_median_ticket_price']

# %%
data = [go.Bar(
            x=avg_price_by_opp['opponent'],
            y=avg_price_by_opp['median_ticket_price'],
            text=(avg_price_by_opp['formatted_median_ticket_price']),
            textposition = 'auto',
            marker=dict(
                color='rgb(158,202,225)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ))]
layout = go.Layout(
    title='Average of Median Ticket Prices for All Nationals Games by Opponent',
    yaxis=dict(
        title='Average Ticket Price ($)'
    )
)

fig = go.Figure(data=data, layout=layout)
py.offline.iplot(fig)
pio.write_image(fig, 'Images/nats_allopponents.png')
# Out:
# <div id="39aa60f1-5f75-4142-b9e7-29b1ce43df97" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("39aa60f1-5f75-4142-b9e7-29b1ce43df97", [{"marker": {"color": "rgb(158,202,225)", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "text": ["$88.14", "$79.11", "$91.25", "$142.50", "$84.00", "$63.83", "$63.00", "$63.86", "$93.67", "$95.00", "$104.29", "$81.16", "$71.50", "$59.33", "$75.37", "$104.16", "$77.43", "$79.29", "$90.33", "$69.00"], "textposition": "auto", "x": ["Arizona Diamondbacks", "Atlanta Braves", "Baltimore Orioles", "Chicago Cubs", "Chicago White Sox", "Cincinnati Reds", "Cleveland Indians", "Colorado Rockies", "Detroit Tigers", "Kansas City Royals", "Los Angeles Dodgers", "Miami Marlins", "Milwaukee Brewers", "Minnesota Twins", "New York Mets", "Philadelphia Phillies", "Pittsburgh Pirates", "San Diego Padres", "San Francisco Giants", "St. Louis Cardinals"], "y": [88.14285714285714, 79.10526315789474, 91.25, 142.5, 84.0, 63.833333333333336, 63.0, 63.857142857142854, 93.66666666666667, 95.0, 104.28571428571429, 81.15789473684211, 71.5, 59.333333333333336, 75.36842105263158, 104.15789473684211, 77.42857142857143, 79.28571428571429, 90.33333333333333, 69.0], "type": "bar", "uid": "9441dfbe-cc37-4034-ab53-7c009c8990ef"}], {"title": "Average of Median Ticket Prices for All Nationals Games by Opponent", "yaxis": {"title": "Average Ticket Price ($)"}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("39aa60f1-5f75-4142-b9e7-29b1ce43df97"));});</script>

# %%
nats_home=reg_season[reg_season['nats_home_away']=='Home']

# %%
home_price_by_opp=pd.DataFrame(nats_home.groupby(['opponent'])['median_ticket_price'].mean())
home_price_by_opp.reset_index(inplace=True)

# %%
formatted_price=[]
for i in range(len(home_price_by_opp['median_ticket_price'])):
    formatted_price.append('${:,.2f}'.format(home_price_by_opp['median_ticket_price'][i]))
home_price_by_opp['formatted_median_ticket_price']=formatted_price

# %%
home_price_by_opp
# Out:
#                  opponent  median_ticket_price formatted_median_ticket_price
# 0    Arizona Diamondbacks            91.750000                        $91.75
# 1          Atlanta Braves            72.111111                        $72.11
# 2       Baltimore Orioles            71.500000                        $71.50
# 3            Chicago Cubs           105.666667                       $105.67
# 4       Chicago White Sox            74.500000                        $74.50
# 5         Cincinnati Reds            48.666667                        $48.67
# 6       Cleveland Indians            63.000000                        $63.00
# 7        Colorado Rockies            79.000000                        $79.00
# 8      Kansas City Royals            95.000000                        $95.00
# 9     Los Angeles Dodgers           103.666667                       $103.67
# 10          Miami Marlins            82.600000                        $82.60
# 11      Milwaukee Brewers            85.666667                        $85.67
# 12          New York Mets            80.888889                        $80.89
# 13  Philadelphia Phillies           113.500000                       $113.50
# 14     Pittsburgh Pirates            85.000000                        $85.00
# 15       San Diego Padres            88.000000                        $88.00
# 16   San Francisco Giants            93.000000                        $93.00
# 17    St. Louis Cardinals            53.000000                        $53.00

# %%
data = [go.Bar(
            x=home_price_by_opp['opponent'],
            y=home_price_by_opp['median_ticket_price'],
            text=(home_price_by_opp['formatted_median_ticket_price']),
            textposition = 'auto',
            marker=dict(
                color='rgb(158,202,225)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ))]
layout = go.Layout(
    title='Average of Median Ticket Prices for Nationals\' Home Games by Opponent',
    yaxis=dict(
        title='Average Ticket Price ($)'
    )
)

fig = go.Figure(data=data, layout=layout)
py.offline.iplot(fig)
pio.write_image(fig, 'Images/nats_homeopponents.png')
# Out:
# <div id="0cce8400-abf1-4560-bab1-e298020ff41f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0cce8400-abf1-4560-bab1-e298020ff41f", [{"marker": {"color": "rgb(158,202,225)", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "text": ["$91.75", "$72.11", "$71.50", "$105.67", "$74.50", "$48.67", "$63.00", "$79.00", "$95.00", "$103.67", "$82.60", "$85.67", "$80.89", "$113.50", "$85.00", "$88.00", "$93.00", "$53.00"], "textposition": "auto", "x": ["Arizona Diamondbacks", "Atlanta Braves", "Baltimore Orioles", "Chicago Cubs", "Chicago White Sox", "Cincinnati Reds", "Cleveland Indians", "Colorado Rockies", "Kansas City Royals", "Los Angeles Dodgers", "Miami Marlins", "Milwaukee Brewers", "New York Mets", "Philadelphia Phillies", "Pittsburgh Pirates", "San Diego Padres", "San Francisco Giants", "St. Louis Cardinals"], "y": [91.75, 72.11111111111111, 71.5, 105.66666666666667, 74.5, 48.666666666666664, 63.0, 79.0, 95.0, 103.66666666666667, 82.6, 85.66666666666667, 80.88888888888889, 113.5, 85.0, 88.0, 93.0, 53.0], "type": "bar", "uid": "23b9f43e-f36c-4f00-94d4-26c58e384889"}], {"title": "Average of Median Ticket Prices for Nationals' Home Games by Opponent", "yaxis": {"title": "Average Ticket Price ($)"}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("0cce8400-abf1-4560-bab1-e298020ff41f"));});</script>

# %%
nats_away=reg_season[reg_season['nats_home_away']=='Away']
away_price_by_opp=pd.DataFrame(nats_away.groupby(['opponent'])['median_ticket_price'].mean())
away_price_by_opp.reset_index(inplace=True)
formatted_price=[]
for i in range(len(away_price_by_opp['median_ticket_price'])):
    formatted_price.append('${:,.2f}'.format(away_price_by_opp['median_ticket_price'][i]))
away_price_by_opp['formatted_median_ticket_price']=formatted_price
away_price_by_opp
# Out:
#                  opponent  median_ticket_price formatted_median_ticket_price
# 0    Arizona Diamondbacks            83.333333                        $83.33
# 1          Atlanta Braves            85.400000                        $85.40
# 2       Baltimore Orioles           111.000000                       $111.00
# 3            Chicago Cubs           179.333333                       $179.33
# 4       Chicago White Sox            93.500000                        $93.50
# 5         Cincinnati Reds            79.000000                        $79.00
# 6        Colorado Rockies            43.666667                        $43.67
# 7          Detroit Tigers            93.666667                        $93.67
# 8     Los Angeles Dodgers           104.750000                       $104.75
# 9           Miami Marlins            79.555556                        $79.56
# 10      Milwaukee Brewers            57.333333                        $57.33
# 11        Minnesota Twins            59.333333                        $59.33
# 12          New York Mets            70.400000                        $70.40
# 13  Philadelphia Phillies            93.777778                        $93.78
# 14     Pittsburgh Pirates            71.750000                        $71.75
# 15       San Diego Padres            72.750000                        $72.75
# 16   San Francisco Giants            87.666667                        $87.67
# 17    St. Louis Cardinals            90.333333                        $90.33

# %%
data = [go.Bar(
            x=away_price_by_opp['opponent'],
            y=away_price_by_opp['median_ticket_price'],
            text=(away_price_by_opp['formatted_median_ticket_price']),
            textposition = 'auto',
            marker=dict(
                color='rgb(158,202,225)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ))]
layout = go.Layout(
    title='Average of Median Ticket Prices for Nationals\' Away Games by Opponent',
    yaxis=dict(
        title='Average Ticket Price ($)'
    )
)

fig = go.Figure(data=data, layout=layout)
py.offline.iplot(fig)
pio.write_image(fig, 'Images/nats_awayopponents.png')
# Out:
# <div id="8261bb6f-453d-48a4-baa3-8c6026b35308" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8261bb6f-453d-48a4-baa3-8c6026b35308", [{"marker": {"color": "rgb(158,202,225)", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "text": ["$83.33", "$85.40", "$111.00", "$179.33", "$93.50", "$79.00", "$43.67", "$93.67", "$104.75", "$79.56", "$57.33", "$59.33", "$70.40", "$93.78", "$71.75", "$72.75", "$87.67", "$90.33"], "textposition": "auto", "x": ["Arizona Diamondbacks", "Atlanta Braves", "Baltimore Orioles", "Chicago Cubs", "Chicago White Sox", "Cincinnati Reds", "Colorado Rockies", "Detroit Tigers", "Los Angeles Dodgers", "Miami Marlins", "Milwaukee Brewers", "Minnesota Twins", "New York Mets", "Philadelphia Phillies", "Pittsburgh Pirates", "San Diego Padres", "San Francisco Giants", "St. Louis Cardinals"], "y": [83.33333333333333, 85.4, 111.0, 179.33333333333334, 93.5, 79.0, 43.666666666666664, 93.66666666666667, 104.75, 79.55555555555556, 57.333333333333336, 59.333333333333336, 70.4, 93.77777777777777, 71.75, 72.75, 87.66666666666667, 90.33333333333333], "type": "bar", "uid": "4d159d1f-9f96-41ad-8f01-cb1bf23bc470"}], {"title": "Average of Median Ticket Prices for Nationals' Away Games by Opponent", "yaxis": {"title": "Average Ticket Price ($)"}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("8261bb6f-453d-48a4-baa3-8c6026b35308"));});</script>
