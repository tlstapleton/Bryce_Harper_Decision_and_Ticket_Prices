# %%
import pandas as pd
import numpy as np
import plotly as py
import plotly.graph_objs as go
py.offline.init_notebook_mode(connected=True)
from scipy.signal import argrelextrema
import datetime
import plotly.io as pio
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
phils_season=pd.read_csv('Before_Bryce_Harper_Decision_Phillies.csv')

# %%
phils_season
# Out:
#      Unnamed: 0                                              event  \
# 0             0  Spring Training: Detroit Tigers at Philadelphi...
# 1             1  Spring Training: Philadelphia Phillies at New ...
# 2             2  Spring Training: Minnesota Twins at Philadelph...
# 3             3  Spring Training: Baltimore Orioles at Philadel...
# 4             4  Spring Training: Philadelphia Phillies at Toro...
# 5             5  Spring Training: Pittsburgh Pirates at Philade...
# 6             6  Spring Training: Philadelphia Phillies at Tamp...
# 7             7  Spring Training: Philadelphia Phillies at Minn...
# 8             8  Spring Training: St. Louis Cardinals at Philad...
# 9             9  Spring Training: Philadelphia Phillies at Toro...
# 10           10  Spring Training: Philadelphia Phillies at Detr...
# 11           11  Spring Training: New York Yankees at Philadelp...
# 12           12  Spring Training: Philadelphia Phillies at Atla...
# 13           13  Spring Training: Toronto Blue Jays at Philadel...
# 14           14  Spring Training: Philadelphia Phillies at Balt...
# 15           15  Spring Training: Tampa Bay Rays at Philadelphi...
# 16           16  Spring Training: Philadelphia Phillies at New ...
# 17           17  Spring Training: Philadelphia Phillies at Tamp...
# 18           18  Spring Training: Philadelphia Phillies at Pitt...
# 19           19  Spring Training: Toronto Blue Jays at Philadel...
# 20           20  Spring Training: Houston Astros at Philadelphi...
# 21           21  Spring Training: New York Yankees at Philadelp...
# 22           22  Spring Training: Philadelphia Phillies at St. ...
# 23           23  Spring Training: Philadelphia Phillies at Hous...
# 24           24  Spring Training: Detroit Tigers at Philadelphi...
# 25           25  Spring Training: Toronto Blue Jays at Philadel...
# 26           26  Spring Training: Philadelphia Phillies at New ...
# 27           27  Spring Training: Philadelphia Phillies at Pitt...
# 28           28  Spring Training: Baltimore Orioles at Philadel...
# 29           29  Spring Training: Tampa Bay Rays at Philadelphi...
# ..          ...                                                ...
# 162         162        Pittsburgh Pirates at Philadelphia Phillies
# 163         163             New York Mets at Philadelphia Phillies
# 164         164             New York Mets at Philadelphia Phillies
# 165         165             New York Mets at Philadelphia Phillies
# 166         166           Philadelphia Phillies at Cincinnati Reds
# 167         167           Philadelphia Phillies at Cincinnati Reds
# 168         168           Philadelphia Phillies at Cincinnati Reds
# 169         169           Philadelphia Phillies at Cincinnati Reds
# 170         170             Philadelphia Phillies at New York Mets
# 171         171             Philadelphia Phillies at New York Mets
# 172         172             Philadelphia Phillies at New York Mets
# 173         173            Atlanta Braves at Philadelphia Phillies
# 174         174            Atlanta Braves at Philadelphia Phillies
# 175         175            Atlanta Braves at Philadelphia Phillies
# 176         176            Atlanta Braves at Philadelphia Phillies
# 177         177            Boston Red Sox at Philadelphia Phillies
# 178         178            Boston Red Sox at Philadelphia Phillies
# 179         179            Philadelphia Phillies at Atlanta Braves
# 180         180            Philadelphia Phillies at Atlanta Braves
# 181         181            Philadelphia Phillies at Atlanta Braves
# 182         182         Philadelphia Phillies at Cleveland Indians
# 183         183         Philadelphia Phillies at Cleveland Indians
# 184         184         Philadelphia Phillies at Cleveland Indians
# 185         185      Philadelphia Phillies at Washington Nationals
# 181  2019-09-19T12:10:00        Atlanta Braves                   85
# 182  2019-09-20T19:10:00     Cleveland Indians                  131
# 183  2019-09-21T19:10:00     Cleveland Indians                  131
# 184  2019-09-22T13:10:00     Cleveland Indians                  132
# 185  2019-09-23T19:05:00  Washington Nationals                  108
# 186  2019-09-24T19:05:00  Washington Nationals                  104
# 187  2019-09-25T19:05:00  Washington Nationals                  104
# 188  2019-09-26T16:05:00  Washington Nationals                  114
# 189  2019-09-27T19:05:00         Miami Marlins                   99
# 190  2019-09-28T18:05:00         Miami Marlins                   99
# 191  2019-09-29T15:05:00         Miami Marlins                  110
#
#     phillies_home_away        date   time
# 0      Spring Training  2019-02-25  13:05
# 1      Spring Training  2019-02-26  13:05
# 2      Spring Training  2019-02-27  13:05
# 3      Spring Training  2019-02-28  13:05
# 4      Spring Training  2019-02-28  13:07
# 5      Spring Training  2019-03-01  13:05
# 6      Spring Training  2019-03-02  13:05
# 7      Spring Training  2019-03-03  13:05
# 8      Spring Training  2019-03-05  13:05
# 9      Spring Training  2019-03-06  13:07
# 10     Spring Training  2019-03-07  13:05
# 11     Spring Training  2019-03-07  13:05
# 12     Spring Training  2019-03-08  18:05
# 13     Spring Training  2019-03-09  13:05
# 14     Spring Training  2019-03-10  13:05
# 15     Spring Training  2019-03-11  13:05
# 16     Spring Training  2019-03-13  18:35
# 17     Spring Training  2019-03-14  13:05
# 18     Spring Training  2019-03-14  13:05
# 19     Spring Training  2019-03-15  13:05
# 20     Spring Training  2019-03-16  13:05
# 21     Spring Training  2019-03-17  13:05
# 22     Spring Training  2019-03-18  13:05
# 23     Spring Training  2019-03-19  13:05
# 24     Spring Training  2019-03-20  13:05
# 25     Spring Training  2019-03-21  13:05
# 26     Spring Training  2019-03-22  18:35
# 27     Spring Training  2019-03-23  13:05
# 28     Spring Training  2019-03-24  13:05
# 29     Spring Training  2019-03-25  13:05
# ..                 ...         ...    ...
# 162               Home  2019-08-28  18:05
# 163               Home  2019-08-30  19:05
# 164               Home  2019-08-31  16:05
# 165               Home  2019-09-01  13:05
# 166               Away  2019-09-02  14:10
# 167               Away  2019-09-03  18:40
# 168               Away  2019-09-04  18:40
# 169               Away  2019-09-05  12:35
# 170               Away  2019-09-06  19:10
# 171               Away  2019-09-07  19:10
# 172               Away  2019-09-08  13:10
# 173               Home  2019-09-09  19:05
# 174               Home  2019-09-10  19:05
# 175               Home  2019-09-11  19:05
# 176               Home  2019-09-12  19:05
# 177               Home  2019-09-14  19:05
# 178               Home  2019-09-15  13:05
# 179               Away  2019-09-17  19:20
# 180               Away  2019-09-18  19:20
# 181               Away  2019-09-19  12:10
# 182               Away  2019-09-20  19:10
# 183               Away  2019-09-21  19:10
# 184               Away  2019-09-22  13:10
# 185               Away  2019-09-23  19:05
# 186               Away  2019-09-24  19:05
# 187               Away  2019-09-25  19:05
# 188               Away  2019-09-26  16:05
# 189               Home  2019-09-27  19:05
# 190               Home  2019-09-28  18:05
# 191               Home  2019-09-29  15:05
#
# [192 rows x 8 columns]

# %%
random_x = phils_season['date']
random_y = phils_season['median_ticket_price']

trace = go.Scatter(
    x = random_x,
    y = random_y
)

title=f'Median Ticket Prices of Philadelphia Phillies Games: {datetime.datetime.today().strftime("%Y-%m-%d")}'

layout = {'title':title,
          'yaxis': {
        'title': 'Median Ticket Price ($)'
    },
    'shapes': [
        # Line Vertical
        {
            'type': 'line',
            'x0': '2019-03-28',
            'x1':'2019-03-28',
            'y0': 0,
            'y1':250,
            'line': {
                'color': 'green',
                'width': 3,
                'dash':'dashdot'
            },
        }
       
    ]
}

data = [trace]
fig = {
    'data': data,
    'layout': layout,
}
py.offline.iplot(fig)
pio.write_image(fig, 'Images/phils_all_games.png')
# Out:
# <div id="8c7a66f1-5482-4903-b822-921406655517" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8c7a66f1-5482-4903-b822-921406655517", [{"x": ["2019-02-25", "2019-02-26", "2019-02-27", "2019-02-28", "2019-02-28", "2019-03-01", "2019-03-02", "2019-03-03", "2019-03-05", "2019-03-06", "2019-03-07", "2019-03-07", "2019-03-08", "2019-03-09", "2019-03-10", "2019-03-11", "2019-03-13", "2019-03-14", "2019-03-14", "2019-03-15", "2019-03-16", "2019-03-17", "2019-03-18", "2019-03-19", "2019-03-20", "2019-03-21", "2019-03-22", "2019-03-23", "2019-03-24", "2019-03-25", "2019-03-28", "2019-03-30", "2019-03-31", "2019-04-02", "2019-04-03", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-12", "2019-04-13", "2019-04-14", "2019-04-15", "2019-04-16", "2019-04-17", "2019-04-18", "2019-04-19", "2019-04-20", "2019-04-21", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-25", "2019-04-26", "2019-04-27", "2019-04-28", "2019-04-30", "2019-05-01", "2019-05-03", "2019-05-04", "2019-05-05", "2019-05-06", "2019-05-07", "2019-05-08", "2019-05-10", "2019-05-11", "2019-05-12", "2019-05-13", "2019-05-14", "2019-05-15", "2019-05-16", "2019-05-17", "2019-05-18", "2019-05-19", "2019-05-20", "2019-05-21", "2019-05-22", "2019-05-23", "2019-05-24", "2019-05-25", "2019-05-26", "2019-05-28", "2019-05-29", "2019-05-30", "2019-05-31", "2019-06-01", "2019-06-02", "2019-06-03", "2019-06-04", "2019-06-05", "2019-06-07", "2019-06-08", "2019-06-09", "2019-06-10", "2019-06-11", "2019-06-12", "2019-06-14", "2019-06-15", "2019-06-16", "2019-06-17", "2019-06-18", "2019-06-19", "2019-06-20", "2019-06-21", "2019-06-22", "2019-06-23", "2019-06-24", "2019-06-25", "2019-06-26", "2019-06-27", "2019-06-28", "2019-06-29", "2019-06-30", "2019-07-02", "2019-07-03", "2019-07-04", "2019-07-05", "2019-07-06", "2019-07-07", "2019-07-12", "2019-07-13", "2019-07-14", "2019-07-15", "2019-07-16", "2019-07-17", "2019-07-18", "2019-07-19", "2019-07-20", "2019-07-21", "2019-07-23", "2019-07-24", "2019-07-26", "2019-07-27", "2019-07-28", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-20", "2019-08-21", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-14", "2019-09-15", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019-09-21", "2019-09-22", "2019-09-23", "2019-09-24", "2019-09-25", "2019-09-26", "2019-09-27", "2019-09-28", "2019-09-29"], "y": [23, 30, 47, 44, 42, 55, 43, 69, 82, 54, 39, 75, 91, 77, 79, 62, 89, 48, 54, 75, 89, 120, 103, 88, 62, 64, 123, 55, 59, 54, 168, 108, 88, 168, 126, 83, 89, 82, 77, 71, 78, 90, 83, 80, 80, 74, 83, 46, 65, 69, 71, 42, 44, 44, 77, 83, 93, 89, 81, 77, 93, 107, 95, 78, 75, 80, 104, 135, 126, 82, 74, 82, 84, 89, 99, 95, 92, 97, 95, 100, 69, 89, 88, 83, 82, 82, 95, 131, 98, 67, 61, 65, 87, 104, 92, 83, 81, 83, 89, 103, 84, 104, 102, 100, 105, 163, 98, 92, 92, 95, 94, 93, 84, 85, 77, 81, 74, 130, 83, 86, 82, 107, 112, 104, 116, 110, 111, 114, 70, 84, 73, 74, 78, 102, 114, 102, 99, 99, 99, 103, 110, 105, 81, 75, 76, 83, 110, 126, 120, 113, 117, 115, 102, 113, 106, 142, 141, 77, 77, 77, 108, 99, 99, 111, 115, 115, 55, 43, 41, 41, 56, 63, 59, 99, 99, 99, 100, 161, 167, 77, 75, 85, 131, 131, 132, 108, 104, 104, 114, 99, 99, 110], "type": "scatter", "uid": "58046904-cdf5-458a-af80-45bde6ae4458"}], {"shapes": [{"line": {"color": "green", "dash": "dashdot", "width": 3}, "type ...

# %%
local_maxima=argrelextrema(phils_season['median_ticket_price'].values, np.greater)
phils_season.iloc[local_maxima]
# Out:
#      Unnamed: 0                                              event  \
# 2             2  Spring Training: Minnesota Twins at Philadelph...
# 5             5  Spring Training: Pittsburgh Pirates at Philade...
# 8             8  Spring Training: St. Louis Cardinals at Philad...
# 12           12  Spring Training: Philadelphia Phillies at Atla...
# 14           14  Spring Training: Philadelphia Phillies at Balt...
# 16           16  Spring Training: Philadelphia Phillies at New ...
# 21           21  Spring Training: New York Yankees at Philadelp...
# 26           26  Spring Training: Philadelphia Phillies at New ...
# 28           28  Spring Training: Baltimore Orioles at Philadel...
# 30           30  Opening Day: Atlanta Braves at Philadelphia Ph...
# 33           33      Philadelphia Phillies at Washington Nationals
# 36           36           Minnesota Twins at Philadelphia Phillies
# 41           41             Philadelphia Phillies at Miami Marlins
# 46           46             New York Mets at Philadelphia Phillies
# 50           50          Philadelphia Phillies at Colorado Rockies
# 56           56             Miami Marlins at Philadelphia Phillies
# 109  2019-06-25T19:05:00         New York Mets                   95
# 113  2019-06-29T16:10:00         Miami Marlins                   85
# 115  2019-07-02T19:20:00        Atlanta Braves                   81
# 117  2019-07-04T19:20:00        Atlanta Braves                  130
# 119  2019-07-06T19:15:00         New York Mets                   86
# 122  2019-07-13T19:15:00  Washington Nationals                  112
# 124  2019-07-15T19:05:00   Los Angeles Dodgers                  116
# 127  2019-07-18T12:35:00   Los Angeles Dodgers                  114
# 129  2019-07-20T19:05:00    Pittsburgh Pirates                   84
# 134  2019-07-27T19:05:00        Atlanta Braves                  114
# 140  2019-08-03T19:05:00     Chicago White Sox                  110
# 147  2019-08-10T13:05:00  San Francisco Giants                  126
# 150  2019-08-14T19:05:00          Chicago Cubs                  117
# 153  2019-08-17T19:05:00      San Diego Padres                  113
# 155  2019-08-20T19:10:00        Boston Red Sox                  142
# 160  2019-08-26T19:05:00    Pittsburgh Pirates                  108
# 171  2019-09-07T19:10:00         New York Mets                   63
# 178  2019-09-15T13:05:00        Boston Red Sox                  167
# 184  2019-09-22T13:10:00     Cleveland Indians                  132
# 188  2019-09-26T16:05:00  Washington Nationals                  114
#
#     phillies_home_away        date   time
# 2      Spring Training  2019-02-27  13:05
# 5      Spring Training  2019-03-01  13:05
# 8      Spring Training  2019-03-05  13:05
# 12     Spring Training  2019-03-08  18:05
# 14     Spring Training  2019-03-10  13:05
# 16     Spring Training  2019-03-13  18:35
# 21     Spring Training  2019-03-17  13:05
# 26     Spring Training  2019-03-22  18:35
# 28     Spring Training  2019-03-24  13:05
# 30                Home  2019-03-28  15:05
# 33                Away  2019-04-02  19:05
# 36                Home  2019-04-06  14:05
# 41                Away  2019-04-12  19:10
# 46                Home  2019-04-17  13:05
# 50                Away  2019-04-21  13:10
# 56                Home  2019-04-27  18:05
# 61                Home  2019-05-04  19:05
# 67                Away  2019-05-11  18:15
# 74                Home  2019-05-18  16:05
# 77                Away  2019-05-21  18:05
# 79                Away  2019-05-23  13:20
# 81                Away  2019-05-25  15:10
# 87                Away  2019-06-01  19:10
# 93                Home  2019-06-08  16:05
# 99                Away  2019-06-15  19:20
# 101               Away  2019-06-17  19:05
# 105               Home  2019-06-21  19:05
# 109               Home  2019-06-25  19:05
# 113               Away  2019-06-29  16:10
# 115               Away  2019-07-02  19:20
# 117               Away  2019-07-04  19:20
# 119               Away  2019-07-06  19:15
# 122               Home  2019-07-13  19:15
# 124               Home  2019-07-15  19:05
# 127               Home  2019-07-18  12:35
# 129               Away  2019-07-20  19:05
# 134               Home  2019-07-27  19:05
# 140               Home  2019-08-03  19:05
# 147               Away  2019-08-10  13:05
# 150               Home  2019-08-14  19:05
# 153               Home  2019-08-17  19:05
# 155               Away  2019-08-20  19:10
# 160               Home  2019-08-26  19:05
# 171               Away  2019-09-07  19:10
# 178               Home  2019-09-15  13:05
# 184               Away  2019-09-22  13:10
# 188               Away  2019-09-26  16:05

# %%
reg_season=phils_season[phils_season['date']>='2019-03-28']

# %%
avg_price_by_opp=pd.DataFrame(reg_season.groupby(['opponent'])['median_ticket_price'].mean())

# %%
# avg_price_by_opp

# %%
avg_price_by_opp.reset_index(inplace=True)

# %%
formatted_price=[]
for i in range(len(avg_price_by_opp['median_ticket_price'])):
    formatted_price.append('${:,.2f}'.format(avg_price_by_opp['median_ticket_price'][i]))
avg_price_by_opp['formatted_median_ticket_price']=formatted_price

# %%
avg_price_by_opp.sort_values(['median_ticket_price'],inplace=True)

# %%
data = [go.Bar(
            x=avg_price_by_opp['opponent'],
            y=avg_price_by_opp['median_ticket_price'],
            text=(avg_price_by_opp['formatted_median_ticket_price']),
            textposition = 'auto',
            marker=dict(
                color='rgb(158,202,225)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ))]
layout = go.Layout(
    title='Average of Median Ticket Prices for All Phillies Games by Opponent',
    yaxis=dict(
        title='Average Ticket Price ($)'
    )
)

fig = go.Figure(data=data, layout=layout)
py.offline.iplot(fig)
pio.write_image(fig, 'Images/phils_allopponents.png')
# Out:
# <div id="ff4111d0-505b-4ff0-b940-291bd1e039cb" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ff4111d0-505b-4ff0-b940-291bd1e039cb", [{"marker": {"color": "rgb(158,202,225)", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "text": ["$66.14", "$76.29", "$77.50", "$79.53", "$79.83", "$80.00", "$81.14", "$84.67", "$85.67", "$88.83", "$91.21", "$98.79", "$104.14", "$104.16", "$105.14", "$106.00", "$110.71", "$121.67", "$131.33", "$152.75"], "textposition": "auto", "x": ["Cincinnati Reds", "Colorado Rockies", "Detroit Tigers", "New York Mets", "Arizona Diamondbacks", "St. Louis Cardinals", "Milwaukee Brewers", "Minnesota Twins", "San Diego Padres", "Pittsburgh Pirates", "Miami Marlins", "Atlanta Braves", "Chicago Cubs", "Washington Nationals", "San Francisco Giants", "Chicago White Sox", "Los Angeles Dodgers", "Kansas City Royals", "Cleveland Indians", "Boston Red Sox"], "y": [66.14285714285714, 76.28571428571429, 77.5, 79.52631578947368, 79.83333333333333, 80.0, 81.14285714285714, 84.66666666666667, 85.66666666666667, 88.83333333333333, 91.21052631578948, 98.78947368421052, 104.14285714285714, 104.15789473684211, 105.14285714285714, 106.0, 110.71428571428571, 121.66666666666667, 131.33333333333334, 152.75], "type": "bar", "uid": "48534450-1302-4096-8127-a7d2d992e95e"}], {"title": "Average of Median Ticket Prices for All Phillies Games by Opponent", "yaxis": {"title": "Average Ticket Price ($)"}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("ff4111d0-505b-4ff0-b940-291bd1e039cb"));});</script>

# %%
phils_home=reg_season[reg_season['phillies_home_away']=='Home']

# %%
home_price_by_opp=pd.DataFrame(phils_home.groupby(['opponent'])['median_ticket_price'].mean())
home_price_by_opp.reset_index(inplace=True)

# %%
formatted_price=[]
for i in range(len(home_price_by_opp['median_ticket_price'])):
    formatted_price.append('${:,.2f}'.format(home_price_by_opp['median_ticket_price'][i]))
home_price_by_opp['formatted_median_ticket_price']=formatted_price

# %%
home_price_by_opp.sort_values(['median_ticket_price'],inplace=True)

# %%
data = [go.Bar(
            x=home_price_by_opp['opponent'],
            y=home_price_by_opp['median_ticket_price'],
            text=(home_price_by_opp['formatted_median_ticket_price']),
            textposition = 'auto',
            marker=dict(
                color='rgb(158,202,225)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ))]
layout = go.Layout(
    title='Average of Median Ticket Prices for Phillies\' Home Games by Opponent',
    yaxis=dict(
        title='Average Ticket Price ($)'
    )
)

fig = go.Figure(data=data, layout=layout)
py.offline.iplot(fig)
pio.write_image(fig, 'Images/phils_homeopponents.png')
# Out:
# <div id="713f06d6-28c5-43c5-b912-a68ba3a5ed01" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("713f06d6-28c5-43c5-b912-a68ba3a5ed01", [{"marker": {"color": "rgb(158,202,225)", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "text": ["$79.00", "$80.50", "$82.33", "$82.33", "$84.67", "$93.78", "$94.33", "$94.33", "$95.20", "$99.00", "$100.30", "$102.00", "$106.00", "$107.00", "$107.90", "$112.75", "$115.00", "$164.00"], "textposition": "auto", "x": ["Detroit Tigers", "Milwaukee Brewers", "Arizona Diamondbacks", "St. Louis Cardinals", "Minnesota Twins", "Washington Nationals", "Colorado Rockies", "Cincinnati Reds", "New York Mets", "San Francisco Giants", "Miami Marlins", "Pittsburgh Pirates", "Chicago White Sox", "San Diego Padres", "Atlanta Braves", "Los Angeles Dodgers", "Chicago Cubs", "Boston Red Sox"], "y": [79.0, 80.5, 82.33333333333333, 82.33333333333333, 84.66666666666667, 93.77777777777777, 94.33333333333333, 94.33333333333333, 95.2, 99.0, 100.3, 102.0, 106.0, 107.0, 107.9, 112.75, 115.0, 164.0], "type": "bar", "uid": "60617975-8de0-4d7a-84d9-06d34a0cca0e"}], {"title": "Average of Median Ticket Prices for Phillies' Home Games by Opponent", "yaxis": {"title": "Average Ticket Price ($)"}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("713f06d6-28c5-43c5-b912-a68ba3a5ed01"));});</script>

# %%
phils_away=reg_season[reg_season['phillies_home_away']=='Away']
away_price_by_opp=pd.DataFrame(phils_away.groupby(['opponent'])['median_ticket_price'].mean())
away_price_by_opp.reset_index(inplace=True)
formatted_price=[]
for i in range(len(away_price_by_opp['median_ticket_price'])):
    formatted_price.append('${:,.2f}'.format(away_price_by_opp['median_ticket_price'][i]))
away_price_by_opp['formatted_median_ticket_price']=formatted_price

# %%
away_price_by_opp.sort_values(['median_ticket_price'],inplace=True)

# %%
data = [go.Bar(
            x=away_price_by_opp['opponent'],
            y=away_price_by_opp['median_ticket_price'],
            text=(away_price_by_opp['formatted_median_ticket_price']),
            textposition = 'auto',
            marker=dict(
                color='rgb(158,202,225)',
                line=dict(
                    color='rgb(8,48,107)',
                    width=1.5),
            ))]
layout = go.Layout(
    title='Average of Median Ticket Prices for Phillies\' Away Games by Opponent',
    yaxis=dict(
        title='Average Ticket Price ($)'
    )
)

fig = go.Figure(data=data, layout=layout)
py.offline.iplot(fig)
pio.write_image(fig, 'Images/phils_awayopponents.png')
# Out:
# <div id="aafcf1a9-7540-43f1-8afc-99842ce67f08" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("aafcf1a9-7540-43f1-8afc-99842ce67f08", [{"marker": {"color": "rgb(158,202,225)", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "text": ["$45.00", "$62.11", "$62.75", "$64.33", "$75.67", "$76.00", "$77.33", "$77.67", "$81.11", "$82.00", "$88.67", "$96.00", "$108.00", "$109.75", "$113.50", "$121.67", "$131.33", "$141.50"], "textposition": "auto", "x": ["Cincinnati Reds", "New York Mets", "Colorado Rockies", "San Diego Padres", "Pittsburgh Pirates", "Detroit Tigers", "Arizona Diamondbacks", "St. Louis Cardinals", "Miami Marlins", "Milwaukee Brewers", "Atlanta Braves", "Chicago Cubs", "Los Angeles Dodgers", "San Francisco Giants", "Washington Nationals", "Kansas City Royals", "Cleveland Indians", "Boston Red Sox"], "y": [45.0, 62.111111111111114, 62.75, 64.33333333333333, 75.66666666666667, 76.0, 77.33333333333333, 77.66666666666667, 81.11111111111111, 82.0, 88.66666666666667, 96.0, 108.0, 109.75, 113.5, 121.66666666666667, 131.33333333333334, 141.5], "type": "bar", "uid": "728b6da6-94ef-4d51-a002-8afec0bcd7ce"}], {"title": "Average of Median Ticket Prices for Phillies' Away Games by Opponent", "yaxis": {"title": "Average Ticket Price ($)"}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("aafcf1a9-7540-43f1-8afc-99842ce67f08"));});</script>
